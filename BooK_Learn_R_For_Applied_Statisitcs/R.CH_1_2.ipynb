# %% [markdown]
# # What R Language

# %% [markdown]
# According to Wikipedia, R programming is for statistical computing and is supported by the R Foundation for Statistical Computing. The R programming language is used by academics and researchers for data analysis and statistical analysis, and R programming’s popularity has risen over Time.
#
# - High-Level and Low-Level Languages: The major difference between the two languages  above is that  ordinary, machine can program and interpret the low-level machine language direct, but however, the high-level machine language needs to be process to back to machine language before a computer can execute it.  Note that R language is inform of high machine language because it shares a lot of similarities with human.
#
# - What are Statistics? : Statistics is a mathematical branch that deals with the analysis of data organisation and interpretation. There are 3 major categories of statistics, Descriptive statistics, Inferential statistics  and Regressions statistics.
#
# - ![EXPERTISE.png](attachment:EXPERTISE.png)
